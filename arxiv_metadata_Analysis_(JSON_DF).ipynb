# %% [markdown]
# # **Arxiv metadata Analytics with PySpark DF: JSON case study**
#
# ### Udemy Course: Best Hands-on Big Data Practices and Use Cases using PySpark
#
# ### Author: Amin Karami (PhD, FHEA)
# #### email: amin.karami@ymail.com

# %%
########## ONLY in Colab ##########
# !pip3 install pyspark
########## ONLY in Colab ##########
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=fa763dcba2e9509321270d91091e6547068c1b9ad5e70157ec8908e1f013d4a9
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
########## ONLY in Ubuntu Machine ##########
# Load Spark engine
# !pip3 install -q findspark
import findspark
findspark.init()
########## ONLY in Ubuntu Machine ##########

# %%
# import SparkSession (It unifies and replaces the older SQLContext, HiveContext, and SparkConf configurations)

from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local[*]').getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://8ec357e52e22:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read and Load Data to Spark
import json

df = spark.read.json("/content/drive/MyDrive/Colab Notebooks/arxiv-metadata-oai-snapshot.json")

df.printSchema()
# Out:
# root
#  |-- abstract: string (nullable = true)
#  |-- authors: string (nullable = true)
#  |-- authors_parsed: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- categories: string (nullable = true)
#  |-- comments: string (nullable = true)
#  |-- doi: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- journal-ref: string (nullable = true)
#  |-- license: string (nullable = true)
#  |-- report-no: string (nullable = true)
#  |-- submitter: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- update_date: string (nullable = true)
#  |-- versions: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- created: string (nullable = true)
#  |    |    |-- version: string (nullable = true)

# %%
# check the partitions // when working with DFs u need to convert to RDD

df.rdd.getNumPartitions()
# Out:
# 25

# %% [markdown]
# ## Question 1: Create a new Schema

# %%
from pyspark.sql.types import *

# %%
Schema = StructType([
    StructField('authors', StringType(), True),
    StructField('categories', StringType(), True),
    StructField('license', StringType(), True),
    StructField('comments', StringType(), True),
    StructField('abstract', StringType(), True),
    StructField('versions', ArrayType(StringType()), True),
    StructField('id', StringType(),True)

])

print(Schema)
# Out:
# StructType([StructField('authors', StringType(), True), StructField('categories', StringType(), True), StructField('license', StringType(), True), StructField('comments', StringType(), True), StructField('abstract', StringType(), True), StructField('versions', ArrayType(StringType(), True), True), StructField('id', StringType(), True)])

# %% [markdown]
# ## Question 2: Binding Data to a Schema

# %%
df = spark.read.json("/content/drive/MyDrive/Colab Notebooks/arxiv-metadata-oai-snapshot.json", schema = Schema)

df.show()
# Out:
# +--------------------+-----------------+--------------------+--------------------+--------------------+--------------------+---------+
# |             authors|       categories|             license|            comments|            abstract|            versions|       id|
# +--------------------+-----------------+--------------------+--------------------+--------------------+--------------------+---------+
# |C. Bal\'azs, E. L...|           hep-ph|                NULL|37 pages, 15 figu...|  A fully differe...|[{"version":"v1",...|0704.0001|
# |Ileana Streinu an...|    math.CO cs.CG|http://arxiv.org/...|To appear in Grap...|  We describe a n...|[{"version":"v1",...|0704.0002|
# |         Hongjun Pan|   physics.gen-ph|                NULL| 23 pages, 3 figures|  The evolution o...|[{"version":"v1",...|0704.0003|
# |        David Callan|          math.CO|                NULL|            11 pages|  We show that a ...|[{"version":"v1",...|0704.0004|
# |Wael Abu-Shammala...|  math.CA math.FA|                NULL|                NULL|  In this paper w...|[{"version":"v1",...|0704.0005|
# |Y. H. Pong and C....|cond-mat.mes-hall|                NULL|6 pages, 4 figure...|  We study the tw...|[{"version":"v1",...|0704.0006|
# |Alejandro Corichi...|            gr-qc|                NULL|16 pages, no figu...|  A rather non-st...|[{"version":"v1",...|0704.0007|
# |     Damian C. Swift|cond-mat.mtrl-sci|http://arxiv.org/...|   Minor corrections|  A general formu...|[{"version":"v1",...|0704.0008|
# |Paul Harvey, Brun...|         astro-ph|                NULL|                NULL|  We discuss the ...|[{"version":"v1",...|0704.0009|
# |  Sergei Ovchinnikov|          math.CO|                NULL|36 pages, 17 figures|  Partial cubes a...|[{"version":"v1",...|0704.0010|
# |Clifton Cunningha...|  math.NT math.AG|http://arxiv.org/...|14 pages; title c...|  In this paper w...|[{"version":"v1",...|0704.0011|
# |         Dohoon Choi|          math.NT|                NULL|                NULL|  Recently, Bruin...|[{"version":"v1",...|0704.0012|
# |Dohoon Choi and Y...|          math.NT|                NULL|                NULL|  Serre obtained ...|[{"version":"v1",...|0704.0013|
# |        Koichi Fujii|  math.CA math.AT|                NULL|  18 pages, 1 figure|  In this article...|[{"version":"v1",...|0704.0014|
# |     Christian Stahn|           hep-th|                NULL|22 pages; signs a...|  The pure spinor...|[{"version":"v1",...|0704.0015|
# |Chao-Hsi Chang, T...|           hep-ph|                NULL|17 pages, 3 figur...|  In this work, w...|[{"version":"v1",...|0704.0016|
# |Nceba Mhlahlo, Da...|         astro-ph|                NULL|10 pages, 11 figu...|  Results from sp...|[{"version":"v1",...|0704.0017|
# |  Andreas Gustavsson|           hep-th|                NULL|20 pages, v2: an ...|  We give a presc...|[{"version":"v1",...|0704.0018|
# |         Norio Konno|  math.PR math.AG|                NULL|6 pages, Journal-...|  In this note we...|[{"version":"v1",...|0704.0019|
# |The BABAR Collabo...|           hep-ex|                NULL|21 pages, 13 post...|  The shape of th...|[{"version":"v1",...|0704.0020|
# +--------------------+-----------------+--------------------+--------------------+--------------------+--------------------+---------+
# only showing top 20 rows

# %% [markdown]
# ## Question 3: Missing values for "comments" and "license" attributes

# %%
#drop specific columns
df = df.drop('id')
#drop null values in a specific column
df = df.dropna(subset='comments')
#replace null values in a specific column
df = df.fillna(value='sifico', subset='license')


df.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |             authors|          categories|             license|            comments|            abstract|            versions|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |C. Bal\'azs, E. L...|              hep-ph|              sifico|37 pages, 15 figu...|  A fully differe...|[{"version":"v1",...|
# |Ileana Streinu an...|       math.CO cs.CG|http://arxiv.org/...|To appear in Grap...|  We describe a n...|[{"version":"v1",...|
# |         Hongjun Pan|      physics.gen-ph|              sifico| 23 pages, 3 figures|  The evolution o...|[{"version":"v1",...|
# |        David Callan|             math.CO|              sifico|            11 pages|  We show that a ...|[{"version":"v1",...|
# |Y. H. Pong and C....|   cond-mat.mes-hall|              sifico|6 pages, 4 figure...|  We study the tw...|[{"version":"v1",...|
# |Alejandro Corichi...|               gr-qc|              sifico|16 pages, no figu...|  A rather non-st...|[{"version":"v1",...|
# |     Damian C. Swift|   cond-mat.mtrl-sci|http://arxiv.org/...|   Minor corrections|  A general formu...|[{"version":"v1",...|
# |  Sergei Ovchinnikov|             math.CO|              sifico|36 pages, 17 figures|  Partial cubes a...|[{"version":"v1",...|
# |Clifton Cunningha...|     math.NT math.AG|http://arxiv.org/...|14 pages; title c...|  In this paper w...|[{"version":"v1",...|
# |        Koichi Fujii|     math.CA math.AT|              sifico|  18 pages, 1 figure|  In this article...|[{"version":"v1",...|
# |     Christian Stahn|              hep-th|              sifico|22 pages; signs a...|  The pure spinor...|[{"version":"v1",...|
# |Chao-Hsi Chang, T...|              hep-ph|              sifico|17 pages, 3 figur...|  In this work, w...|[{"version":"v1",...|
# |Nceba Mhlahlo, Da...|            astro-ph|              sifico|10 pages, 11 figu...|  Results from sp...|[{"version":"v1",...|
# |  Andreas Gustavsson|              hep-th|              sifico|20 pages, v2: an ...|  We give a presc...|[{"version":"v1",...|
# |         Norio Konno|     math.PR math.AG|              sifico|6 pages, Journal-...|  In this note we...|[{"version":"v1",...|
# |The BABAR Collabo...|              hep-ex|              sifico|21 pages, 13 post...|  The shape of th...|[{"version":"v1",...|
# |Vanessa Casagrand...|nlin.PS physics.c...|              sifico|  5 pages, 4 figures|  Spatiotemporal ...|[{"version":"v1",...|
# |Simon J.A. Malham...|             math.NA|              sifico| 20 pages, 4 figures|  We present Lie ...|[{"version":"v1",...|
# |M. A. Loukitcheva...|            astro-ph|              sifico|4 pages, 2 figure...|  The very nature...|[{"version":"v1",...|
# |A.A. Serga, M. Ko...|             nlin.PS|              sifico|First appeared in...|  The formation o...|[{"version":"v1",...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 4: Get the author names who published a paper in a 'math' category

# %%
#register DF to be used in SparkSQL

#start by "math"

df.createOrReplaceTempView('Archive')
sql_query = """
              SELECT authors FROM Archive WHERE categories LIKE "math%"

"""

spark.sql(sql_query).show()

spark.sql(sql_query).count()
# Out:
# +--------------------+
# |             authors|
# +--------------------+
# |Ileana Streinu an...|
# |        David Callan|
# |  Sergei Ovchinnikov|
# |Clifton Cunningha...|
# |        Koichi Fujii|
# |         Norio Konno|
# |Simon J.A. Malham...|
# |Robert P. C. de M...|
# |  P\'eter E. Frenkel|
# |          Mihai Popa|
# |   Debashish Goswami|
# |      Mikkel {\O}bro|
# |Nabil L. Youssef,...|
# |         Boris Rubin|
# |         A. I. Molev|
# | Branko J. Malesevic|
# |   John W. Robertson|
# |     Yu.N. Kosovtsov|
# |        Osamu Fujino|
# |Stephen C. Power ...|
# +--------------------+
# only showing top 20 rows
# 304590

# %% [markdown]
# ## Question 5: Get linceses with 5 or more letters in the "abstract"

# %%
sql_query = """ SELECT distinct(license) FROM Archive
                WHERE abstract REGEXP '%\(([A-Za-z][^_ /\\<>]{5,})\)%'
            """
spark.sql(sql_query).show()
# Out:
# +--------------------+
# |             license|
# +--------------------+
# |http://arxiv.org/...|
# |http://creativeco...|
# |http://creativeco...|
# |http://creativeco...|
# |              sifico|
# +--------------------+

# %% [markdown]
# ## Question 6: Extract the statistic of the number of pages for unknown licenses

# %%
import re
def get_page(line):
  search= re.findall("\d+ pages", line)
  if search:
    return int(search[0].split(" ")[0]) #return for example "12 pages" then we take the first one by split " "
  else:
    return 0 #rows that have no pages

# %%
spark.udf.register("PageNumbers", get_page)

sql_query = """
        SELECT AVG(PageNumbers(comments)) AS AVG, SUM(PageNumbers(comments)) AS SUM FROM Archive
        WHERE license = 'sifico'

"""

spark.sql(sql_query).show()
# Out:
# +------------------+---------+
# |               AVG|      SUM|
# +------------------+---------+
# |13.368011068572079|5642584.0|
# +------------------+---------+
